# %%
import numpy as np
import pandas as pd
from scipy.stats import spearmanr, kendalltau, pearsonr, boxcox
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/root/ml_mate_exoplanet/Data/feeds.csv', sep=',')

var_df = df[['field1', 'field2']]
var_df.head()
# Out:
#    field1  field2
# 0    17.5    76.2
# 1    17.5    76.0
# 2    17.4    76.1
# 3    17.4    75.6
# 4    32.3    36.1

# %%
plt.scatter(var_df.field1, var_df.field2)
plt.show()

# %%
corr, _ = pearsonr(var_df.field1, var_df.field2)
R_sq = corr**2

print(corr, _)
# Out:
# -0.9183821271884752 0.0
